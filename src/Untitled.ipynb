# %%
import pandas as pd

# %%
from src.data.load_data import (load_transactions, load_artciles, load_customers)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.data.load_data import (load_transactions, load_artciles, load_customers)
#
# ModuleNotFoundError: No module named 'src'
